# %%
import pandas as pd
import numpy as np
from sklearn import svm
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.metrics import precision_recall_fscore_support
from sklearn.pipeline import Pipeline
import time
from sklearn.externals import joblib
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV

tcontext = 120

# Load features
features = np.load('features_tcontext_' + str(tcontext) + '_frameSize_1024.npz')
features = features['a']
features = features[:10000,:]
features += np.finfo(np.float32).eps
features = np.delete(features, 60, 1) #deletes a constant column
features = np.delete(features, 60, 1) #deletes a constant column
labels = features[:,-1].astype(int)
features = features[:, :features.shape[1] - 1]

with open("features_length.txt", 'r') as f:
    features_length = [line.rstrip('\n') for line in f]

features_names = list()
for i in features_length:
    marker = i.find(':')
    f_name = i[:marker]
    values = int(i[marker+2:])
    for j in range(values):
        features_names.append(f_name + str('_')+ str(j))
del features_names[60:62] # deletes the feature names which are constant

# Prepare data
imputer = SimpleImputer()
features = imputer.fit_transform(features)
le = preprocessing.LabelEncoder()
labels = le.fit_transform(labels)


# Split data
features_train, features_val, labels_train, labels_val = train_test_split(features, labels, test_size=0.2, random_state = 42)
features_train_df = pd.DataFrame(data = features_train, columns = features_names)
features_val_df = pd.DataFrame(data = features_val, columns = features_names)


def grid_search(clf, X, y):
    k_features = [5, 10, 20, 40, 80, 84]
    params = dict(anova_filter__k=k_features,
                  svm__kernel=['rbf'], svm__C=[0.01, 0.1, 1, 3],
                  svm__degree=[1, 3, 5, 7], svm__gamma=[0.01, 0.1, 1,3])
    gs = GridSearchCV(clf, param_grid=params, cv=10, verbose=2)
    gs.fit(X, y)
    print ("Best estimator:")
    print (gs.best_estimator_)
    print ("Best parameters:")
    print (gs.best_params_)
    print ("Best score:")
    print (gs.best_score_)

    return gs

estimators = [("scale", preprocessing.StandardScaler()),
                  ('anova_filter', SelectKBest(f_classif, k=80)),
                  ('svm', svm.SVC(decision_function_shape='ovo'))]
clf = Pipeline(estimators)
gs = grid_search(clf, features_train, labels_train)


# Load features
features = np.load('features_tcontext_' + str(tcontext) + '_frameSize_1024.npz')
features = features['a']
#features = features[:10000,:]
features += np.finfo(np.float32).eps
features = np.delete(features, 60, 1) #deletes a constant column
features = np.delete(features, 60, 1) #deletes a constant column
labels = features[:,-1].astype(int)
features = features[:, :features.shape[1] - 1]

with open("features_length.txt", 'r') as f:
    features_length = [line.rstrip('\n') for line in f]

features_names = list()
for i in features_length:
    marker = i.find(':')
    f_name = i[:marker]
    values = int(i[marker+2:])
    for j in range(values):
        features_names.append(f_name + str('_')+ str(j))
del features_names[60:62] # deletes the feature names which are constant

# Prepare data
imputer = SimpleImputer()
features = imputer.fit_transform(features)
le = preprocessing.LabelEncoder()
labels = le.fit_transform(labels)


# Split data
features_train, features_val, labels_train, labels_val = train_test_split(features, labels, test_size=0.2, random_state = 42)
features_train_df = pd.DataFrame(data = features_train, columns = features_names)
features_val_df = pd.DataFrame(data = features_val, columns = features_names)

# Select best k features
selector = SelectKBest(f_classif, k=40)
selector.fit(features_train_df, labels_train)
# Get columns to keep
cols = selector.get_support(indices=True)
cols = [features_names[i] for i in cols]

clf_svm = gs.best_estimator_
clf_svm.fit(features_train, labels_train)

model_filename = './tcontext_'+ str(tcontext) + '/models/svm/svm_best_model.sav'
joblib.dump(clf_svm, open(model_filename, 'wb'))
# Out:
# Fitting 2 folds for each of 48 candidates, totalling 96 fits
# [CV] anova_filter__k=40, svm__C=3, svm__degree=1, svm__gamma=0.01, svm__kernel=rbf
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=1, svm__gamma=0.01, svm__kernel=rbf, total=   0.5s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=1, svm__gamma=0.01, svm__kernel=rbf
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=1, svm__gamma=0.01, svm__kernel=rbf, total=   0.4s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=1, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=1, svm__gamma=0.1, svm__kernel=rbf, total=   0.8s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=1, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=1, svm__gamma=0.1, svm__kernel=rbf, total=   0.7s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=1, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=1, svm__gamma=1, svm__kernel=rbf, total=   2.5s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=1, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=1, svm__gamma=1, svm__kernel=rbf, total=   2.4s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=1, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=1, svm__gamma=3, svm__kernel=rbf, total=   2.6s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=1, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=1, svm__gamma=3, svm__kernel=rbf, total=   3.0s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=3, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=3, svm__gamma=0.01, svm__kernel=rbf, total=   0.4s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=3, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=3, svm__gamma=0.01, svm__kernel=rbf, total=   0.4s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=3, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=3, svm__gamma=0.1, svm__kernel=rbf, total=   0.8s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=3, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=3, svm__gamma=0.1, svm__kernel=rbf, total=   0.7s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=3, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=3, svm__gamma=1, svm__kernel=rbf, total=   2.6s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=3, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=3, svm__gamma=1, svm__kernel=rbf, total=   2.8s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=3, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=3, svm__gamma=3, svm__kernel=rbf, total=   2.9s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=3, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=3, svm__gamma=3, svm__kernel=rbf, total=   2.9s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=5, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=5, svm__gamma=0.01, svm__kernel=rbf, total=   0.4s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=5, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=5, svm__gamma=0.01, svm__kernel=rbf, total=   0.4s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=5, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=5, svm__gamma=0.1, svm__kernel=rbf, total=   0.8s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=5, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=5, svm__gamma=0.1, svm__kernel=rbf, total=   0.7s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=5, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=5, svm__gamma=1, svm__kernel=rbf, total=   2.6s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=5, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=5, svm__gamma=1, svm__kernel=rbf, total=   2.4s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=5, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=5, svm__gamma=3, svm__kernel=rbf, total=   2.8s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=5, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=5, svm__gamma=3, svm__kernel=rbf, total=   2.7s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=7, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=7, svm__gamma=0.01, svm__kernel=rbf, total=   0.4s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=7, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=7, svm__gamma=0.01, svm__kernel=rbf, total=   0.4s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=7, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=7, svm__gamma=0.1, svm__kernel=rbf, total=   0.8s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=7, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=7, svm__gamma=0.1, svm__kernel=rbf, total=   0.8s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=7, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=7, svm__gamma=1, svm__kernel=rbf, total=   2.9s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=7, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=7, svm__gamma=1, svm__kernel=rbf, total=   3.0s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=7, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=7, svm__gamma=3, svm__kernel=rbf, total=   2.7s
# [CV] anova_filter__k=40, svm__C=3, svm__degree=7, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=40, svm__C=3, svm__degree=7, svm__gamma=3, svm__kernel=rbf, total=   2.8s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=1, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=1, svm__gamma=0.01, svm__kernel=rbf, total=   0.8s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=1, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=1, svm__gamma=0.01, svm__kernel=rbf, total=   0.7s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=1, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=1, svm__gamma=0.1, svm__kernel=rbf, total=   2.5s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=1, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=1, svm__gamma=0.1, svm__kernel=rbf, total=   2.6s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=1, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=1, svm__gamma=1, svm__kernel=rbf, total=   4.6s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=1, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=1, svm__gamma=1, svm__kernel=rbf, total=   4.9s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=1, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=1, svm__gamma=3, svm__kernel=rbf, total=   5.3s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=1, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=1, svm__gamma=3, svm__kernel=rbf, total=   4.9s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=3, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=3, svm__gamma=0.01, svm__kernel=rbf, total=   0.9s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=3, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=3, svm__gamma=0.01, svm__kernel=rbf, total=   0.8s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=3, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=3, svm__gamma=0.1, svm__kernel=rbf, total=   2.4s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=3, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=3, svm__gamma=0.1, svm__kernel=rbf, total=   2.3s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=3, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=3, svm__gamma=1, svm__kernel=rbf, total=   5.0s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=3, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=3, svm__gamma=1, svm__kernel=rbf, total=   5.7s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=3, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=3, svm__gamma=3, svm__kernel=rbf, total=   5.0s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=3, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=3, svm__gamma=3, svm__kernel=rbf, total=   4.9s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=5, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=5, svm__gamma=0.01, svm__kernel=rbf, total=   0.8s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=5, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=5, svm__gamma=0.01, svm__kernel=rbf, total=   0.8s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=5, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=5, svm__gamma=0.1, svm__kernel=rbf, total=   2.5s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=5, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=5, svm__gamma=0.1, svm__kernel=rbf, total=   2.5s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=5, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=5, svm__gamma=1, svm__kernel=rbf, total=   5.1s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=5, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=5, svm__gamma=1, svm__kernel=rbf, total=   5.0s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=5, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=5, svm__gamma=3, svm__kernel=rbf, total=   5.5s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=5, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=5, svm__gamma=3, svm__kernel=rbf, total=   5.6s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=7, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=7, svm__gamma=0.01, svm__kernel=rbf, total=   0.9s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=7, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=7, svm__gamma=0.01, svm__kernel=rbf, total=   0.9s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=7, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=7, svm__gamma=0.1, svm__kernel=rbf, total=   2.5s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=7, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=7, svm__gamma=0.1, svm__kernel=rbf, total=   2.5s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=7, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=7, svm__gamma=1, svm__kernel=rbf, total=   5.7s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=7, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=7, svm__gamma=1, svm__kernel=rbf, total=   5.2s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=7, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=7, svm__gamma=3, svm__kernel=rbf, total=   5.6s
# [CV] anova_filter__k=80, svm__C=3, svm__degree=7, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=80, svm__C=3, svm__degree=7, svm__gamma=3, svm__kernel=rbf, total=   5.5s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=1, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=1, svm__gamma=0.01, svm__kernel=rbf, total=   1.0s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=1, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=1, svm__gamma=0.01, svm__kernel=rbf, total=   1.0s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=1, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=1, svm__gamma=0.1, svm__kernel=rbf, total=   3.1s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=1, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=1, svm__gamma=0.1, svm__kernel=rbf, total=   3.2s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=1, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=1, svm__gamma=1, svm__kernel=rbf, total=   5.3s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=1, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=1, svm__gamma=1, svm__kernel=rbf, total=   5.5s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=1, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=1, svm__gamma=3, svm__kernel=rbf, total=   5.6s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=1, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=1, svm__gamma=3, svm__kernel=rbf, total=   6.3s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=3, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=3, svm__gamma=0.01, svm__kernel=rbf, total=   1.1s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=3, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=3, svm__gamma=0.01, svm__kernel=rbf, total=   1.0s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=3, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=3, svm__gamma=0.1, svm__kernel=rbf, total=   3.1s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=3, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=3, svm__gamma=0.1, svm__kernel=rbf, total=   3.2s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=3, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=3, svm__gamma=1, svm__kernel=rbf, total=   5.8s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=3, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=3, svm__gamma=1, svm__kernel=rbf, total=   6.0s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=3, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=3, svm__gamma=3, svm__kernel=rbf, total=   5.9s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=3, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=3, svm__gamma=3, svm__kernel=rbf, total=   5.8s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=5, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=5, svm__gamma=0.01, svm__kernel=rbf, total=   1.1s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=5, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=5, svm__gamma=0.01, svm__kernel=rbf, total=   1.1s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=5, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=5, svm__gamma=0.1, svm__kernel=rbf, total=   3.1s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=5, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=5, svm__gamma=0.1, svm__kernel=rbf, total=   3.3s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=5, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=5, svm__gamma=1, svm__kernel=rbf, total=   6.3s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=5, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=5, svm__gamma=1, svm__kernel=rbf, total=   5.6s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=5, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=5, svm__gamma=3, svm__kernel=rbf, total=   5.8s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=5, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=5, svm__gamma=3, svm__kernel=rbf, total=   6.1s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=7, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=7, svm__gamma=0.01, svm__kernel=rbf, total=   1.0s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=7, svm__gamma=0.01, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=7, svm__gamma=0.01, svm__kernel=rbf, total=   0.9s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=7, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=7, svm__gamma=0.1, svm__kernel=rbf, total=   3.0s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=7, svm__gamma=0.1, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=7, svm__gamma=0.1, svm__kernel=rbf, total=   3.3s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=7, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=7, svm__gamma=1, svm__kernel=rbf, total=   5.3s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=7, svm__gamma=1, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=7, svm__gamma=1, svm__kernel=rbf, total=   5.6s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=7, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=7, svm__gamma=3, svm__kernel=rbf, total=   6.0s
# [CV] anova_filter__k=84, svm__C=3, svm__degree=7, svm__gamma=3, svm__kernel=rbf
# [CV]  anova_filter__k=84, svm__C=3, svm__degree=7, svm__gamma=3, svm__kernel=rbf, total=   6.3s
# [Parallel(n_jobs=1)]: Done  96 out of  96 | elapsed:  6.5min finished
# Best estimator:
# Pipeline(memory=None,
#      steps=[('scale', StandardScaler(copy=True, with_mean=True, with_std=True)), ('anova_filter', SelectKBest(k=40, score_func=<function f_classif at 0x1a1c439268>)), ('svm', SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovo', degree=1, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False))])
# Best parameters:
# {'anova_filter__k': 40, 'svm__C': 3, 'svm__degree': 1, 'svm__gamma': 0.1, 'svm__kernel': 'rbf'}
# Best score:
# 0.958125
